# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Read csv files

# %%
data=pd.read_csv('top-5000-youtube-channels.csv')

# %% [markdown]
# ### 1. Display All Rows Except the Last 5 rows Using Head Method

# %%
data.head(-5)
# Out:
#          Rank Grade                      Channel name Video Uploads  \
# 0         1st  A++                             Zee TV         82757
# 1         2nd  A++                           T-Series         12661
# 2         3rd  A++         Cocomelon - Nursery Rhymes           373
# 3         4th  A++                          SET India         27323
# 4         5th  A++                                WWE         36756
# ...       ...   ...                               ...           ...
# 4990  4,991st   B+      Ho Ngoc Ha's Official Channel           208
# 4991  4,992nd   B+               Toys to Learn Colors            11
# 4992  4,993rd   B+                              КАZКА            25
# 4993  4,994th   B+   United CUBE (CUBE Entertainment…          1055
# 4994  4,995th   B+                      Wings Marathi          1735
#
#      Subscribers  Video views
# 0       18752951  20869786591
# 1       61196302  47548839843
# 2       19238251   9793305082
# ...

# %% [markdown]
# ### 2. Display All Rows Except the First 5 Rows Using Tail Method

# %%
data.tail(-5)
# Out:
#          Rank Grade           Channel name Video Uploads Subscribers  \
# 5         6th  A++              Movieclips         30243    17149705
# 6         7th  A++              netd müzik          8500    11373567
# 7         8th  A++   ABS-CBN Entertainment        100147    12149206
# 8         9th  A++         Ryan ToysReview          1140    16082927
# 9        10th  A++             Zee Marathi         74607     2841811
# ...       ...   ...                    ...           ...         ...
# 4995  4,996th   B+          Uras Benlioğlu           706     2072942
# 4996  4,997th   B+       HI-TECH MUSIC LTD           797     1055091
# 4997  4,998th   B+             Mastersaint           110     3265735
# 4998  4,999th   B+          Bruce McIntosh          3475       32990
# 4999  5,000th   B+               SehatAQUA           254       21172
#
#       Video views
# 5     16618094724
# 6     23898730764
# 7     17202609850
# 8     24518098041
# 9      2591830307
# ...           ...
# ...

# %% [markdown]
# ### 3. Find Shape of our Dataset(Number of Rows And Number of Columns)

# %%
shapes=data.shape

# %%
shapes
# Out:
# (5000, 6)

# %%
rows,columns=shapes

# %%
rows
# Out:
# 5000

# %%
columns
# Out:
# 6

# %% [markdown]
# ### 4. Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           5000 non-null   object
#  1   Grade          5000 non-null   object
#  2   Channel name   5000 non-null   object
#  3   Video Uploads  5000 non-null   object
#  4   Subscribers    5000 non-null   object
#  5   Video views    5000 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 234.5+ KB

# %% [markdown]
# ### 5. Get Overall statistics About The Dataframe

# %%
data.describe()
# Out:
#         Video views
# count  5.000000e+03
# mean   1.071449e+09
# std    2.003844e+09
# min    7.500000e+01
# 25%    1.862329e+08
# 50%    4.820548e+08
# 75%    1.124368e+09
# max    4.754884e+10

# %% [markdown]
# ### 6. Data Cleaning(Replace '--' to NaN)

# %%
data.columns
# Out:
# Index(['Rank', 'Grade', 'Channel name', 'Video Uploads', 'Subscribers',
#        'Video views'],
#       dtype='object')

# %%
data=data.replace('--',np.nan,regex=True)

# %%
data.head(20)
# Out:
#     Rank Grade                Channel name Video Uploads Subscribers  \
# 0    1st  A++                       Zee TV         82757    18752951
# 1    2nd  A++                     T-Series         12661    61196302
# 2    3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3    4th  A++                    SET India         27323    31180559
# 4    5th  A++                          WWE         36756    32852346
# 5    6th  A++                   Movieclips         30243    17149705
# 6    7th  A++                   netd müzik          8500    11373567
# 7    8th  A++        ABS-CBN Entertainment        100147    12149206
# 8    9th  A++              Ryan ToysReview          1140    16082927
# 9   10th  A++                  Zee Marathi         74607     2841811
# 10  11th   A+              5-Minute Crafts          2085    33492951
# 11  12th   A+              Canal KondZilla           822    39409726
# 12  13th   A+             Like Nastya Vlog           150     7662886
# ...

# %% [markdown]
# ### 7. Check Null Values In The Dataset

# %%
data.isnull()
# Out:
#        Rank  Grade  Channel name  Video Uploads  Subscribers  Video views
# 0     False  False         False          False        False        False
# 1     False  False         False          False        False        False
# 2     False  False         False          False        False        False
# 3     False  False         False          False        False        False
# 4     False  False         False          False        False        False
# ...     ...    ...           ...            ...          ...          ...
# 4995  False  False         False          False        False        False
# 4996  False  False         False          False        False        False
# 4997  False  False         False          False        False        False
# 4998  False  False         False          False        False        False
# 4999  False  False         False          False        False        False
#
# [5000 rows x 6 columns]

# %%
data[data['Subscribers'].isnull()]
# Out:
#          Rank Grade                   Channel name Video Uploads Subscribers  \
# 17       18th   A+                 Vlad and Nikita            53         NaN
# 108     109th    A                          BIGFUN           373         NaN
# 115     116th    A    Bee Kids Games - Children TV           740         NaN
# 142     143rd    A             ChiChi TV Siêu Nhân           421         NaN
# 143     144th    A                  MusicTalentNow          1487         NaN
# ...       ...   ...                            ...           ...         ...
# 4941  4,942nd   B+                            GMTV           183         NaN
# 4948  4,949th   B+               Keivon ToysReview           468         NaN
# 4956  4,957th   B+                       CLICKNEWS          2661         NaN
# 4961  4,962nd   B+                ONE Championship           905         NaN
# 4990  4,991st   B+   Ho Ngoc Ha's Official Channel           208         NaN
#
#       Video views
# 17     1428274554
# ...

# %% [markdown]
# ### 8. Data Cleaning[Subscribers Column , Video Uploads Column, Video views Column ]

# %%
   data.columns
# Out:
# Index(['Rank', 'Grade', 'Channel name', 'Video Uploads', 'Subscribers',
#        'Video views'],
#       dtype='object')

# %%
data=data.fillna({'Video Uploads':0,'Subscribers':0})

# %%
data[['Video Uploads','Subscribers']]=data[['Video Uploads','Subscribers']].astype(int)

# %%
data.dtypes
# Out:
# Rank             object
# Grade            object
# Channel name     object
# Video Uploads     int32
# Subscribers       int32
# Video views       int64
# dtype: object

# %% [markdown]
# ### 9.Visualization Of Above Data

# %%
data.columns
# Out:
# Index(['Rank', 'Grade', 'Channel name', 'Video Uploads', 'Subscribers',
#        'Video views'],
#       dtype='object')

# %%
Top5=data['Subscribers'].head()

# %%
fig,((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,ncols=2,figsize=(60,30))
fig.suptitle("Top-5-Youtube-Channels Dataset",y=1)
ax1.pie(data['Subscribers'].head(),labels=data['Channel name'].head(),autopct="%0.2f%%",radius=1.7,shadow=True,textprops={'fontsize':40})
ax1.set_title("YouTube's Most Subscribed Channel",y=1.4)
#SET FONTSIZE
font_size=40
for item in ([ax1.title,ax1.xaxis.label,ax1.yaxis.label]+ax1.get_xticklabels()+ax1.get_yticklabels()):
    item.set_fontsize(font_size)
ax2.bar(data['Channel name'].head(),data['Video Uploads'].head())
#SET FONTSIZE
font_size=40
for item in ([ax2.title,ax2.xaxis.label,ax2.yaxis.label]+ax2.get_xticklabels()+ax2.get_yticklabels()):
    item.set_fontsize(font_size)

plt.tight_layout()
plt.show()

# %% [markdown]
# ###
